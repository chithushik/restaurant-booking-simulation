# %%
# !pip install mesa
# Out:
# Requirement already satisfied: mesa in c:\users\pclam\anaconda3\lib\site-packages (3.5.1)
# Requirement already satisfied: numpy in c:\users\pclam\anaconda3\lib\site-packages (from mesa) (2.3.5)
# Requirement already satisfied: pandas in c:\users\pclam\anaconda3\lib\site-packages (from mesa) (2.3.3)
# Requirement already satisfied: scipy in c:\users\pclam\anaconda3\lib\site-packages (from mesa) (1.16.3)
# Requirement already satisfied: tqdm in c:\users\pclam\anaconda3\lib\site-packages (from mesa) (4.67.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\pclam\anaconda3\lib\site-packages (from pandas->mesa) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\pclam\anaconda3\lib\site-packages (from pandas->mesa) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\pclam\anaconda3\lib\site-packages (from pandas->mesa) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\pclam\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas->mesa) (1.17.0)
# Requirement already satisfied: colorama in c:\users\pclam\anaconda3\lib\site-packages (from tqdm->mesa) (0.4.6)

# %%
import random
import mesa
from mesa import Agent, Model
from mesa.space import MultiGrid
from mesa.datacollection import DataCollector
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import numpy as np
import io
import base64

# %%
# NEW FEATURE (Restaurant Simulation): Define possible group sizes
GROUP_SIZES = [2, 4, 6]

class CustomerAgent(Agent):
    """
    A restaurant customer agent.
    Each customer has a group size (2, 4, or 6 people).
    """
    
    def __init__(self, unique_id, model):
        super().__init__(model)
        self.unique_id = unique_id
        self.booking = 0  # 1 = booked a table, 0 = not booked
        self.waiting = False  # True if waiting for a table
        self.group_size = random.choice(GROUP_SIZES)  # Random group size
        self.pos = None
        print(f"👤 Customer {self.unique_id} arrived with group size {self.group_size}")

    def step(self):
        """
        Each step, the customer tries to find a table.
        """
        # Get all tables that can fit this group
        available_tables = self.model.get_tables_for_size(self.group_size)
        
        if not self.waiting:
            # Not waiting – try to book a table
            if available_tables:
                # Pick a random table
                table_pos = random.choice(available_tables)
                # Check if the table is empty
                cell_content = self.model.grid.get_cell_list_contents([table_pos])
                if len(cell_content) == 0:
                    # Success! Move to the table
                    self.model.grid.move_agent(self, table_pos)
                    self.booking = 1
                    self.waiting = False
                    print(f"✅ Customer {self.unique_id} (group {self.group_size}) booked table at {table_pos}")
                else:
                    # Table is taken – join waiting list
                    self.waiting = True
                    print(f"❌ Customer {self.unique_id} (group {self.group_size}) – table taken. Waiting...")
            else:
                # No table of this size exists
                self.waiting = True
                print(f"❌ Customer {self.unique_id} (group {self.group_size}) – no table available. Waiting...")
        else:
            # Already waiting – try again
            if available_tables:
                table_pos = random.choice(available_tables)
                cell_content = self.model.grid.get_cell_list_contents([table_pos])
                if len(cell_content) == 0:
                    self.model.grid.move_agent(self, table_pos)
                    self.booking = 1
                    self.waiting = False
                    print(f"✅✅ Customer {self.unique_id} FINALLY booked table at {table_pos} from waiting list!")
                else:
                    print(f"⏳ Customer {self.unique_id} still waiting...")
            else:
                print(f"⏳ Customer {self.unique_id} still waiting (no table size)...")

# %%
class RestaurantModel(Model):
    """
    The main restaurant model.
    Manages the grid, tables, and customers.
    """
    
    def __init__(self, num_agents, grid_width, grid_height,
                 num_tables_2=3, num_tables_4=3, num_tables_6=2):
        super().__init__()
        self.num_agents = num_agents
        self.grid = MultiGrid(grid_width, grid_height, True)
        self._agents = []  # All agents
        self.tables = []   # List of (position, size)

        # Place tables in the bottom half of the grid
        available_cells = []
        for x in range(grid_width):
            for y in range(grid_height // 2, grid_height):
                available_cells.append((x, y))
        random.shuffle(available_cells)
        
        idx = 0
        for size, count in [(2, num_tables_2), (4, num_tables_4), (6, num_tables_6)]:
            for _ in range(count):
                if idx < len(available_cells):
                    pos = available_cells[idx]
                    idx += 1
                    self.tables.append((pos, size))
                    print(f"📊 Placed {size}-seat table at {pos}")

        # Create customer agents
        for i in range(self.num_agents):
            a = CustomerAgent(i, self)
            # Place customers in the top half of the grid (waiting area)
            x = random.randrange(self.grid.width)
            y = random.randrange(0, self.grid.height // 2)
            self.grid.place_agent(a, (x, y))
            a.pos = (x, y)
            self._agents.append(a)

        # Data collector
        self.datacollector = DataCollector(
            model_reporters={
                "Occupied Tables": lambda m: sum(1 for a in m._agents if a.booking == 1),
                "Waiting Customers": lambda m: sum(1 for a in m._agents if a.waiting),
            },
            agent_reporters={
                "Booking": "booking",
                "Group Size": "group_size",
                "Waiting": "waiting"
            }
        )

    def get_tables_for_size(self, group_size):
        """
        Return a list of table positions that can fit the group.
        A table fits if its capacity >= group_size.
        """
        return [pos for pos, size in self.tables if size >= group_size]

    def step(self):
        """Run one step of the simulation."""
        self.datacollector.collect(self)
        agents = self._agents.copy()
        random.shuffle(agents)
        for agent in agents:
            agent.step()

# %%
def draw_restaurant_grid(model):
    """
    Draw the restaurant grid showing tables and customers.
    """
    fig, ax = plt.subplots(figsize=(10, 10))
    
    # Draw the grid lines
    for x in range(model.grid.width):
        for y in range(model.grid.height):
            rect = patches.Rectangle((x, y), 1, 1, linewidth=0.5, edgecolor='lightgray', facecolor='none')
            ax.add_patch(rect)
    
    # Draw tables
    for (x, y), size in model.tables:
        # Color by table size
        color = {2: 'lightblue', 4: 'lightgreen', 6: 'lightyellow'}.get(size, 'white')
        rect = patches.Rectangle((x + 0.05, y + 0.05), 0.9, 0.9, edgecolor='black', facecolor=color)
        ax.add_patch(rect)
        ax.text(x + 0.5, y + 0.5, f'{size}p', fontsize=10, ha='center', va='center', fontweight='bold')
    
    # Draw customers
    for agent in model._agents:
        x, y = agent.pos
        if agent.booking == 1:
            # Booked – green dot
            color = 'green'
            label = f'{agent.group_size}'
        else:
            # Waiting – red dot
            color = 'red'
            label = 'W'
        ax.plot(x + 0.5, y + 0.5, 'o', color=color, markersize=15)
        ax.text(x + 0.5, y + 0.5, label, fontsize=8, ha='center', va='center', color='white', fontweight='bold')
    
    ax.set_xlim(0, model.grid.width)
    ax.set_ylim(0, model.grid.height)
    ax.set_aspect('equal')
    ax.invert_yaxis()
    ax.set_title("Restaurant Table Booking - Green=Booked, Red=Waiting", fontsize=14)
    
    # Add legend
    from matplotlib.patches import Patch
    legend_elements = [
        Patch(facecolor='lightblue', label='2-seat table'),
        Patch(facecolor='lightgreen', label='4-seat table'),
        Patch(facecolor='lightyellow', label='6-seat table'),
        Patch(facecolor='green', label='Booked customer'),
        Patch(facecolor='red', label='Waiting customer')
    ]
    ax.legend(handles=legend_elements, loc='upper right')
    
    plt.show()

# %%
# Create the restaurant
print("=== Starting Restaurant Simulation ===\n")
model = RestaurantModel(
    num_agents=20,
    grid_width=10,
    grid_height=10,
    num_tables_2=4,
    num_tables_4=3,
    num_tables_6=2
)

print("\n--- Running Simulation ---\n")

# Run for 10 steps
for step in range(10):
    model.step()
    occupied = sum(1 for a in model._agents if a.booking == 1)
    waiting = sum(1 for a in model._agents if a.waiting)
    print(f"Step {step+1}: Occupied = {occupied}, Waiting = {waiting}")

# Show final results
print("\n--- Final Results ---")
data = model.datacollector.get_model_vars_dataframe()
print(data)

# Draw the final grid
draw_restaurant_grid(model)
# Out:
# === Starting Restaurant Simulation ===
#
# 📊 Placed 2-seat table at (6, 7)
# 📊 Placed 2-seat table at (4, 8)
# 📊 Placed 2-seat table at (8, 6)
# 📊 Placed 2-seat table at (2, 8)
# 📊 Placed 4-seat table at (2, 6)
# 📊 Placed 4-seat table at (5, 8)
# 📊 Placed 4-seat table at (8, 8)
# 📊 Placed 6-seat table at (0, 7)
# 📊 Placed 6-seat table at (5, 6)
# 👤 Customer 0 arrived with group size 6
# 👤 Customer 1 arrived with group size 2
# 👤 Customer 2 arrived with group size 2
# 👤 Customer 3 arrived with group size 2
# 👤 Customer 4 arrived with group size 4
# 👤 Customer 5 arrived with group size 6
# 👤 Customer 6 arrived with group size 2
# 👤 Customer 7 arrived with group size 6
# 👤 Customer 8 arrived with group size 6
# 👤 Customer 9 arrived with group size 2
# 👤 Customer 10 arrived with group size 2
# 👤 Customer 11 arrived with group size 4
# 👤 Customer 12 arrived with group size 4
# 👤 Customer 13 arrived with group size 2
# 👤 Customer 14 arrived with group size 6
# 👤 Customer 15 arrived with group size 2
# 👤 Customer 16 arrived with group size 4
# 👤 Customer 17 arrived with group size 2
# 👤 Customer 18 arrived with group size 6
# 👤 Customer 19 arrived with group size 6
#
# --- Running Simulation ---
#
# ✅ Customer 0 (group 6) booked table at (0, 7)
# ✅ Customer 3 (group 2) booked table at (8, 8)
# ✅ Customer 18 (group 6) booked table at (5, 6)
# ❌ Customer 5 (group 6) – table taken. Waiting...
# ❌ Customer 9 (group 2) – table taken. Waiting...
# ❌ Customer 11 (group 4) – table taken. Waiting...
# ✅ Customer 17 (group 2) booked table at (5, 8)
# ✅ Customer 10 (group 2) booked table at (4, 8)
# ❌ Customer 6 (group 2) – table taken. Waiting...
# ❌ Customer 19 (group 6) – table taken. Waiting...
# ❌ Customer 1 (group 2) – table taken. Waiting...
# ❌ Customer 12 (group 4) – table taken. Waiting...
# ❌ Customer 8 (group 6) – table taken. Waiting...
# ❌ Customer 15 (group 2) – table taken. Waiting...
# ❌ Customer 4 (group 4) – table taken. Waiting...
# ✅ Customer 2 (group 2) booked table at (2, 8)
# ❌ Customer 7 (group 6) – table taken. Waiting...
# ❌ Customer 16 (group 4) – table taken. Waiting...
# ❌ Customer 14 (group 6) – table taken. Waiting...
# ✅ Customer 13 (group 2) booked table at (6, 7)
# Step 1: Occupied = 7, Waiting = 13
# ⏳ Customer 12 still waiting...
# ❌ Customer 3 (group 2) – table taken. Waiting...
# ⏳ Customer 5 still waiting...
# ❌ Customer 17 (group 2) – table taken. Waiting...
# ⏳ Customer 4 still waiting...
# ⏳ Customer 7 still waiting...
# ❌ Customer 0 (group 6) – table taken. Waiting...
# ⏳ Customer 14 still waiting...
# ⏳ Customer 6 still waiting...
# ❌ Customer 2 (group 2) – table taken. Waiting...
# ⏳ Customer 16 still waiting...
# ❌ Customer 13 (group 2) – table taken. Waiting...
# ⏳ Customer 11 still waiting...
# ⏳ Customer 15 still waiting...
# ⏳ Customer 8 still waiting...
# ❌ Customer 10 (group 2) – table taken. Waiting...
# ⏳ Customer 19 still waiting...
# ❌ Customer 18 (group 6) – table taken. Waiting...
# ⏳ Customer 9 still waiting...
# ⏳ Customer 1 still waiting...
# Step 2: Occupied = 7, Waiting = 20
# ⏳ Customer 11 still waiting...
# ⏳ Customer 17 still waiting...
# ⏳ Customer 3 still waiting...
# ⏳ Customer 8 still waiting...
# ⏳ Customer 6 still waiting...
# ⏳ Customer 0 still waiting...
# ⏳ Customer 12 still waiting...
# ⏳ Customer 9 still waiting...
# ⏳ Customer 5 still waiting...
# ✅✅ Customer 1 FINALLY booked table at (2, 6) from waiting list!
# ⏳ Customer 16 still waiting...
# ⏳ Customer 19 still waiting...
# ⏳ Customer 13 still waiting...
# ⏳ Customer 7 still waiting...
# ⏳ Customer 2 still waiting...
# ⏳ Customer 18 still waiting...
# ⏳ Customer 4 still waiting...
# ⏳ Customer 15 still waiting...
# ⏳ Customer 10 still waiting...
# ⏳ Customer 14 still waiting...
# Step 3: Occupied = 8, Waiting = 19
# ⏳ Customer 8 still waiting...
# ⏳ Customer 17 still waiting...
# ⏳ Customer 10 still waiting...
# ⏳ Customer 7 still waiting...
# ❌ Customer 1 (group 2) – table taken. Waiting...
# ⏳ Customer 2 still waiting...
# ⏳ Customer 0 still waiting...
# ⏳ Customer 15 still waiting...
# ⏳ Customer 16 still waiting...
# ⏳ Customer 11 still waiting...
# ⏳ Customer 14 still waiting...
# ⏳ Customer 5 still waiting...
# ⏳ Customer 4 still waiting...
# ⏳ Customer 12 still waiting...
# ⏳ Customer 3 still waiting...
# ⏳ Customer 18 still waiting...
# ⏳ Customer 9 still waiting...
# ⏳ Customer 6 still waiting...
# ⏳ Customer 13 still waiting...
# ⏳ Customer 19 still waiting...
# Step 4: Occupied = 8, Waiting = 20
# ⏳ Customer 18 still waiting...
# ⏳ Customer 7 still waiting...
# ⏳ Customer 2 still waiting...
# ⏳ Customer 9 still waiting...
# ⏳ Customer 3 still waiting...
# ⏳ Customer 10 still waiting...
# ⏳ Customer 19 still waiting...
# ⏳ Customer 13 still waiting...
# ⏳ Customer 1 still waiting...
# ⏳ Customer 0 still waiting...
# ⏳ Customer 14 still waiting...
# ✅✅ Customer 6 FINALLY booked table at (8, 6) from waiting list!
# ⏳ Customer 4 still waiting...
# ⏳ Customer 17 still waiting...
# ⏳ Customer 5 still waiting...
# ⏳ Customer 11 still waiting...
# ⏳ Customer 8 still waiting...
# ⏳ Customer 16 still waiting...
# ⏳ Customer 15 still waiting...
# ⏳ Customer 12 still waiting...
# Step 5: Occupied = 9, Waiting = 19
# ⏳ Customer 17 still waiting...
# ⏳ Customer 15 still waiting...
# ⏳ Customer 0 still waiting...
# ⏳ Customer 5 still waiting...
# ❌ Customer 6 (group 2) – table taken. Waiting...
# ⏳ Customer 14 still waiting...
# ⏳ Customer 8 still waiting...
# ⏳ Customer 10 still waiting...
# ⏳ Customer 9 still waiting...
# ⏳ Customer 1 still waiting...
# ⏳ Customer 11 still waiting...
# ⏳ Customer 2 still waiting...
# ⏳ Customer 18 still waiting...
# ⏳ Customer 16 still waiting...
# ⏳ Customer 12 still waiting...
# ⏳ Customer 19 still waiting...
# ⏳ Customer 13 still waiting...
# ⏳ Customer 4 still waiting...
# ⏳ Customer 3 still waiting...
# ⏳ Customer 7 still waiting...
# Step 6: Occupied = 9, Waiting = 20
# ⏳ Customer 5 still waiting...
# ⏳ Customer 16 still waiting...
# ⏳ Customer 15 still waiting...
# ⏳ Customer 0 still waiting...
# ⏳ Customer 2 still waiting...
# ⏳ Customer 12 still waiting...
# ⏳ Customer 1 still waiting...
# ⏳ Customer 10 still waiting...
# ⏳ Customer 8 still waiting...
# ⏳ Customer 18 still waiting...
# ⏳ Customer 7 still waiting...
# ⏳ Customer 19 still waiting...
# ⏳ Customer 6 still waiting...
# ⏳ Customer 14 still waiting...
# ⏳ Customer 13 still waiting...
# ⏳ Customer 17 still waiting...
# ⏳ Customer 3 still waiting...
# ⏳ Customer 9 still waiting...
# ⏳ Customer 11 still waiting...
# ⏳ Customer 4 still waiting...
# Step 7: Occupied = 9, Waiting = 20
# ⏳ Customer 7 still waiting...
# ⏳ Customer 18 still waiting...
# ⏳ Customer 1 still waiting...
# ⏳ Customer 14 still waiting...
# ⏳ Customer 16 still waiting...
# ⏳ Customer 12 still waiting...
# ⏳ Customer 0 still waiting...
# ⏳ Customer 15 still waiting...
# ⏳ Customer 11 still waiting...
# ⏳ Customer 4 still waiting...
# ⏳ Customer 6 still waiting...
# ⏳ Customer 13 still waiting...
# ⏳ Customer 17 still waiting...
# ⏳ Customer 19 still waiting...
# ⏳ Customer 3 still waiting...
# ⏳ Customer 2 still waiting...
# ⏳ Customer 10 still waiting...
# ⏳ Customer 5 still waiting...
# ⏳ Customer 9 still waiting...
# ⏳ Customer 8 still waiting...
# Step 8: Occupied = 9, Waiting = 20
# ⏳ Customer 9 still waiting...
# ⏳ Customer 3 still waiting...
# ⏳ Customer 19 still waiting...
# ⏳ Customer 8 still waiting...
# ⏳ Customer 5 still waiting...
# ⏳ Customer 6 still waiting...
# ⏳ Customer 10 still waiting...
# ⏳ Customer 2 still waiting...
# ⏳ Customer 0 still waiting...
# ⏳ Customer 12 still waiting...
# ⏳ Customer 11 still waiting...
# ⏳ Customer 13 still waiting...
# ⏳ Customer 4 still waiting...
# ⏳ Customer 15 still waiting...
# ⏳ Customer 1 still waiting...
# ⏳ Customer 14 still waiting...
# ⏳ Customer 16 still waiting...
# ⏳ Customer 18 still waiting...
# ⏳ Customer 17 still waiting...
# ⏳ Customer 7 still waiting...
# Step 9: Occupied = 9, Waiting = 20
# ⏳ Customer 15 still waiting...
# ⏳ Customer 1 still waiting...
# ⏳ Customer 4 still waiting...
# ⏳ Customer 13 still waiting...
# ⏳ Customer 12 still waiting...
# ⏳ Customer 17 still waiting...
# ⏳ Customer 14 still waiting...
# ⏳ Customer 10 still waiting...
# ⏳ Customer 0 still waiting...
# ⏳ Customer 6 still waiting...
# ⏳ Customer 3 still waiting...
# ⏳ Customer 8 still waiting...
# ⏳ Customer 11 still waiting...
# ⏳ Customer 19 still waiting...
# ⏳ Customer 16 still waiting...
# ⏳ Customer 5 still waiting...
# ⏳ Customer 18 still waiting...
# ⏳ Customer 7 still waiting...
# ⏳ Customer 2 still waiting...
# ⏳ Customer 9 still waiting...
# Step 10: Occupied = 9, Waiting = 20
#
# --- Final Results ---
#    Occupied Tables  Waiting Customers
# 0                0                  0
# 1                7                 13
# 2                7                 20
# 3                8                 19
# 4                8                 20
# 5                9                 19
# 6                9                 20
# 7                9                 20
# 8                9                 20
# 9                9                 20

# %%
# %%writefile restaurant_app.py
# Out:
# UsageError: %%writefile is a cell magic, but the cell body is empty.

# %%
# %%writefile restaurant_app.py
"""
Restaurant Table Booking Simulation – Web Interface (Solara)
NEW FEATURE (Restaurant Simulation): Interactive web interface.
"""

import solara
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import random
import numpy as np
from mesa.space import MultiGrid
import io
import base64

# ---------- Simulation Code (copied from notebook) ----------
GROUP_SIZES = [2, 4, 6]

class CustomerAgent:
    def __init__(self, unique_id, model):
        self.unique_id = unique_id
        self.model = model
        self.booking = 0
        self.waiting = False
        self.group_size = random.choice(GROUP_SIZES)
        self.pos = None

    def step(self):
        available_tables = self.model.get_tables_for_size(self.group_size)
        
        if not self.waiting:
            if available_tables:
                table_pos = random.choice(available_tables)
                cell_content = self.model.grid.get_cell_list_contents([table_pos])
                if len(cell_content) == 0:
                    self.model.grid.move_agent(self, table_pos)
                    self.booking = 1
                    self.waiting = False
                else:
                    self.waiting = True
            else:
                self.waiting = True
        else:
            if available_tables:
                table_pos = random.choice(available_tables)
                cell_content = self.model.grid.get_cell_list_contents([table_pos])
                if len(cell_content) == 0:
                    self.model.grid.move_agent(self, table_pos)
                    self.booking = 1
                    self.waiting = False

class RestaurantModel:
    def __init__(self, num_agents, grid_width, grid_height,
                 num_tables_2=3, num_tables_4=3, num_tables_6=2):
        self.num_agents = num_agents
        self.grid = MultiGrid(grid_width, grid_height, True)
        self._agents = []
        self.tables = []

        # Place tables in bottom half
        available_cells = [(x, y) for x in range(grid_width) for y in range(grid_height//2, grid_height)]
        random.shuffle(available_cells)
        idx = 0
        for size, count in [(2, num_tables_2), (4, num_tables_4), (6, num_tables_6)]:
            for _ in range(count):
                if idx < len(available_cells):
                    pos = available_cells[idx]
                    idx += 1
                    self.tables.append((pos, size))

        # Create agents in top half
        for i in range(self.num_agents):
            a = CustomerAgent(i, self)
            x = random.randrange(self.grid.width)
            y = random.randrange(0, self.grid.height//2)
            self.grid.place_agent(a, (x, y))
            a.pos = (x, y)
            self._agents.append(a)

    def get_tables_for_size(self, group_size):
        return [pos for pos, size in self.tables if size >= group_size]

    def step(self):
        agents = self._agents.copy()
        random.shuffle(agents)
        for agent in agents:
            agent.step()

    def get_stats(self):
        total = len(self._agents)
        booked = sum(1 for a in self._agents if a.booking == 1)
        waiting = sum(1 for a in self._agents if a.waiting)
        return total, booked, waiting

# ---------- Visualization Functions ----------
def fig_to_base64(fig):
    buf = io.BytesIO()
    fig.savefig(buf, format='png')
    buf.seek(0)
    img_base64 = base64.b64encode(buf.read()).decode('utf-8')
    plt.close(fig)
    return f"data:image/png;base64,{img_base64}"

def draw_restaurant_image(model):
    """Return a base64 image string of the restaurant grid."""
    fig, ax = plt.subplots(figsize=(8, 8))
    
    # Draw grid
    for x in range(model.grid.width):
        for y in range(model.grid.height):
            rect = patches.Rectangle((x, y), 1, 1, linewidth=0.5, edgecolor='lightgray', facecolor='none')
            ax.add_patch(rect)
    
    # Draw tables
    for (x, y), size in model.tables:
        color = {2: 'lightblue', 4: 'lightgreen', 6: 'lightyellow'}.get(size, 'white')
        rect = patches.Rectangle((x + 0.05, y + 0.05), 0.9, 0.9, edgecolor='black', facecolor=color)
        ax.add_patch(rect)
        ax.text(x + 0.5, y + 0.5, f'{size}p', fontsize=10, ha='center', va='center', fontweight='bold')
    
    # Draw agents
    for agent in model._agents:
        x, y = agent.pos
        if agent.booking == 1:
            color = 'green'
            label = f'{agent.group_size}'
        else:
            color = 'red'
            label = 'W'
        ax.plot(x + 0.5, y + 0.5, 'o', color=color, markersize=15)
        ax.text(x + 0.5, y + 0.5, label, fontsize=8, ha='center', va='center', color='white', fontweight='bold')
    
    ax.set_xlim(0, model.grid.width)
    ax.set_ylim(0, model.grid.height)
    ax.set_aspect('equal')
    ax.invert_yaxis()
    ax.set_title("Restaurant Table Booking", fontsize=14)
    
    from matplotlib.patches import Patch
    legend_elements = [
        Patch(facecolor='lightblue', label='2-seat table'),
        Patch(facecolor='lightgreen', label='4-seat table'),
        Patch(facecolor='lightyellow', label='6-seat table'),
        Patch(facecolor='green', label='Booked customer'),
        Patch(facecolor='red', label='Waiting customer')
    ]
    ax.legend(handles=legend_elements, loc='upper right')
    
    img_src = fig_to_base64(fig)
    return img_src

# ---------- Solara Web Interface ----------
@solara.component
def Page():
    num_agents, set_num_agents = solara.use_state(20)
    width, set_width = solara.use_state(10)
    height, set_height = solara.use_state(10)
    steps, set_steps = solara.use_state(10)
    tables_2, set_tables_2 = solara.use_state(4)
    tables_4, set_tables_4 = solara.use_state(3)
    tables_6, set_tables_6 = solara.use_state(2)
    results, set_results = solara.use_state(None)
    img_src, set_img_src = solara.use_state(None)

    def run_simulation():
        m = RestaurantModel(
            num_agents=num_agents,
            grid_width=width,
            grid_height=height,
            num_tables_2=tables_2,
            num_tables_4=tables_4,
            num_tables_6=tables_6
        )
        for _ in range(steps):
            m.step()
        total, booked, waiting = m.get_stats()
        set_results((total, booked, waiting))
        set_img_src(draw_restaurant_image(m))

    # Sidebar with controls
    with solara.Row(style={"height": "100vh", "overflow": "hidden"}):
        # Left sidebar
        with solara.Column(style={"width": "340px", "padding": "20px", "border-right": "1px solid #ddd", "overflow-y": "auto", "flex-shrink": "0"}):
            solara.Markdown("## 🍽️ Restaurant Controls")
            solara.Markdown("---")
            solara.SliderInt("👥 Customers", value=num_agents, min=5, max=50, step=1, on_value=set_num_agents)
            solara.SliderInt("📐 Grid Width", value=width, min=5, max=20, step=1, on_value=set_width)
            solara.SliderInt("📐 Grid Height", value=height, min=5, max=20, step=1, on_value=set_height)
            solara.Markdown("---")
            solara.Markdown("### Table Counts")
            solara.SliderInt("🪑 2-Seat Tables", value=tables_2, min=0, max=10, step=1, on_value=set_tables_2)
            solara.SliderInt("🪑 4-Seat Tables", value=tables_4, min=0, max=10, step=1, on_value=set_tables_4)
            solara.SliderInt("🪑 6-Seat Tables", value=tables_6, min=0, max=10, step=1, on_value=set_tables_6)
            solara.Markdown("---")
            solara.SliderInt("⚡ Steps to Run", value=steps, min=1, max=20, step=1, on_value=set_steps)
            solara.Markdown("---")
            solara.Button("▶ Run Simulation", on_click=run_simulation, color="primary")

        # Right content
        with solara.Column(style={"flex": "1", "padding": "20px", "overflow-y": "auto"}):
            solara.Markdown("## 📊 Simulation Results")

            if results is not None:
                total, booked, waiting = results
                solara.Markdown(f"**Total Customers:** {total}")
                solara.Markdown(f"**Booked:** {booked}  ({booked/total*100:.1f}%)")
                solara.Markdown(f"**Waiting:** {waiting}")
            else:
                solara.Markdown("Press **Run Simulation** to see results.")

            if img_src is not None:
                solara.Markdown(f'<img src="{img_src}" style="max-width:100%; height:auto;" />')
# Out:
# Writing restaurant_app.py

# %%
# !pip install solara
# Out:
# Requirement already satisfied: solara in c:\users\pclam\anaconda3\lib\site-packages (1.61.0)
# Requirement already satisfied: solara-server==1.61.0 in c:\users\pclam\anaconda3\lib\site-packages (from solara-server[dev,starlette]==1.61.0->solara) (1.61.0)
# Requirement already satisfied: solara-ui==1.61.0 in c:\users\pclam\anaconda3\lib\site-packages (from solara-ui[all]==1.61.0->solara) (1.61.0)
# Requirement already satisfied: click>=7.1.0 in c:\users\pclam\anaconda3\lib\site-packages (from solara-server==1.61.0->solara-server[dev,starlette]==1.61.0->solara) (8.2.1)
# Requirement already satisfied: filelock in c:\users\pclam\anaconda3\lib\site-packages (from solara-server==1.61.0->solara-server[dev,starlette]==1.61.0->solara) (3.20.0)
# Requirement already satisfied: ipykernel!=7.0.0,!=7.0.1 in c:\users\pclam\anaconda3\lib\site-packages (from solara-server==1.61.0->solara-server[dev,starlette]==1.61.0->solara) (6.31.0)
# Requirement already satisfied: jinja2 in c:\users\pclam\anaconda3\lib\site-packages (from solara-server==1.61.0->solara-server[dev,starlette]==1.61.0->solara) (3.1.6)
# Requirement already satisfied: jupyter-client in c:\users\pclam\anaconda3\lib\site-packages (from solara-server==1.61.0->solara-server[dev,starlette]==1.61.0->solara) (8.6.3)
# Requirement already satisfied: nbformat in c:\users\pclam\anaconda3\lib\site-packages (from solara-server==1.61.0->solara-server[dev,starlette]==1.61.0->solara) (5.10.4)
# Requirement already satisfied: rich-click in c:\users\pclam\anaconda3\lib\site-packages (from solara-server==1.61.0->solara-server[dev,starlette]==1.61.0->solara) (1.9.8)
# Requirement already satisfied: watchdog in c:\users\pclam\anaconda3\lib\site-packages (from solara-server[dev,starlette]==1.61.0->solara) (4.0.2)
# Requirement already satisfied: watchfiles in c:\users\pclam\anaconda3\lib\site-packages (from solara-server[dev,starlette]==1.61.0->solara) (1.2.0)
# Requirement already satisfied: starlette in c:\users\pclam\anaconda3\lib\site-packages (from solara-server[dev,starlette]==1.61.0->solara) (1.6.0)
# Requirement already satisfied: uvicorn in c:\users\pclam\anaconda3\lib\site-packages (from solara-server[dev,starlette]==1.61.0->solara) (0.52.3)
# Requirement already satisfied: websockets in c:\users\pclam\anaconda3\lib\site-packages (from solara-server[dev,starlette]==1.61.0->solara) (15.0.1)
# Requirement already satisfied: executing in c:\users\pclam\anaconda3\lib\site-packages (from solara-ui==1.61.0->solara-ui[all]==1.61.0->solara) (2.2.1)
# Requirement already satisfied: humanize in c:\users\pclam\anaconda3\lib\site-packages (from solara-ui==1.61.0->solara-ui[all]==1.61.0->solara) (4.16.0)
# Requirement already satisfied: ipyvue>=1.9.0 in c:\users\pclam\anaconda3\lib\site-packages (from solara-ui==1.61.0->solara-ui[all]==1.61.0->solara) (3.0.0)
# Requirement already satisfied: ipyvuetify>=1.6.10 in c:\users\pclam\anaconda3\lib\site-packages (from solara-ui==1.61.0->solara-ui[all]==1.61.0->solara) (3.0.0)
# Requirement already satisfied: ipywidgets>=7.7 in c:\users\pclam\anaconda3\lib\site-packages (from solara-ui==1.61.0->solara-ui[all]==1.61.0->solara) (8.1.7)
# Requirement already satisfied: reacton>=1.9 in c:\users\pclam\anaconda3\lib\site-packages (from solara-ui==1.61.0->solara-ui[all]==1.61.0->solara) (1.10.2)
# Requirement already satisfied: requests in c:\users\pclam\anaconda3\lib\site-packages (from solara-ui==1.61.0->solara-ui[all]==1.61.0->solara) (2.32.5)
# Requirement already satisfied: cachetools in c:\users\pclam\anaconda3\lib\site-packages (from solara-ui[all]==1.61.0->solara) (5.5.1)
# Requirement already satisfied: markdown in c:\users\pclam\anaconda3\lib\site-packages (from solara-ui[all]==1.61.0->solara) (3.8)
# Requirement already satisfied: numpy in c:\users\pclam\anaconda3\lib\site-packages (from solara-ui[all]==1.61.0->solara) (2.3.5)
# Requirement already satisfied: pillow in c:\users\pclam\anaconda3\lib\site-packages (from solara-ui[all]==1.61.0->solara) (12.0.0)
# Requirement already satisfied: pygments in c:\users\pclam\anaconda3\lib\site-packages (from solara-ui[all]==1.61.0->solara) (2.19.2)
# Requirement already satisfied: pymdown-extensions in c:\users\pclam\anaconda3\lib\site-packages (from solara-ui[all]==1.61.0->solara) (11.0.1)
# Requirement already satisfied: colorama in c:\users\pclam\anaconda3\lib\site-packages (from click>=7.1.0->solara-server==1.61.0->solara-server[dev,starlette]==1.61.0->solara) (0.4.6)
# Requirement already satisfied: comm>=0.1.1 in c:\users\pclam\anaconda3\lib\site-packages (from ipykernel!=7.0.0,!=7.0.1->solara-server==1.61.0->solara-server[dev,starlette]==1.61.0->solara) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\pclam\anaconda3\lib\site-packages (from ipykernel!=7.0.0,!=7.0.1->solara-server==1.61.0->solara-server[dev,starlette]==1.61.0->solara) (1.8.16)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\pclam\anaconda3\lib\site-packages (from ipykernel!=7.0.0,!=7.0.1->solara-server==1.61.0->solara-server[dev,starlette]==1.61.0->solara) (9.7.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\pclam\anaconda3\lib\site-packages (from ipykernel!=7.0.0,!=7.0.1->solara-server==1.61.0->solara-server[dev,starlette]==1.61.0->solara) (5.8.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\pclam\anaconda3\lib\site-packages (from ipykernel!=7.0.0,!=7.0.1->solara-server==1.61.0->solara-server[dev,starlette]==1.61.0->solara) (0.2.1)
# Requirement already satisfied: nest-asyncio>=1.4 in c:\users\pclam\anaconda3\lib\site-packages (from ipykernel!=7.0.0,!=7.0.1->solara-server==1.61.0->solara-server[dev,starlette]==1.61.0->solara) (1.6.0)
# Requirement already satisfied: packaging>=22 in c:\users\pclam\anaconda3\lib\site-packages (from ipykernel!=7.0.0,!=7.0.1->solara-server==1.61.0->solara-server[dev,starlette]==1.61.0->solara) (25.0)
# Requirement already satisfied: psutil>=5.7 in c:\users\pclam\anaconda3\lib\site-packages (from ipykernel!=7.0.0,!=7.0.1->solara-server==1.61.0->solara-server[dev,starlette]==1.61.0->solara) (7.0.0)
# Requirement already satisfied: pyzmq>=25 in c:\users\pclam\anaconda3\lib\site-packages (from ipykernel!=7.0.0,!=7.0.1->solara-server==1.61.0->solara-server[dev,starlette]==1.61.0->solara) (27.1.0)
# Requirement already satisfied: tornado>=6.2 in c:\users\pclam\anaconda3\lib\site-packages (from ipykernel!=7.0.0,!=7.0.1->solara-server==1.61.0->solara-server[dev,starlette]==1.61.0->solara) (6.5.1)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\pclam\anaconda3\lib\site-packages (from ipykernel!=7.0.0,!=7.0.1->solara-server==1.61.0->solara-server[dev,starlette]==1.61.0->solara) (5.14.3)
# Requirement already satisfied: decorator>=4.3.2 in c:\users\pclam\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel!=7.0.0,!=7.0.1->solara-server==1.61.0->solara-server[dev,starlette]==1.61.0->solara) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in c:\users\pclam\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel!=7.0.0,!=7.0.1->solara-server==1.61.0->solara-server[dev,starlette]==1.61.0->solara) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in c:\users\pclam\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel!=7.0.0,!=7.0.1->solara-server==1.61.0->solara-server[dev,starlette]==1.61.0->solara) (0.19.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\pclam\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel!=7.0.0,!=7.0.1->solara-server==1.61.0->solara-server[dev,starlette]==1.61.0->solara) (3.0.52)
# Requirement already satisfied: stack_data>=0.6.0 in c:\users\pclam\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel!=7.0.0,!=7.0.1->solara-server==1.61.0->solara-server[dev,starlette]==1.61.0->solara) (0.6.3)
# Requirement already satisfied: wcwidth in c:\users\pclam\anaconda3\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel!=7.0.0,!=7.0.1->solara-server==1.61.0->solara-server[dev,starlette]==1.61.0->solara) (0.2.13)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\pclam\anaconda3\lib\site-packages (from ipywidgets>=7.7->solara-ui==1.61.0->solara-ui[all]==1.61.0->solara) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\users\pclam\anaconda3\lib\site-packages (from ipywidgets>=7.7->solara-ui==1.61.0->solara-ui[all]==1.61.0->solara) (3.0.15)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\pclam\anaconda3\lib\site-packages (from jedi>=0.18.1->ipython>=7.23.1->ipykernel!=7.0.0,!=7.0.1->solara-server==1.61.0->solara-server[dev,starlette]==1.61.0->solara) (0.8.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\pclam\anaconda3\lib\site-packages (from jupyter-client->solara-server==1.61.0->solara-server[dev,starlette]==1.61.0->solara) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\pclam\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel!=7.0.0,!=7.0.1->solara-server==1.61.0->solara-server[dev,starlette]==1.61.0->solara) (4.5.0)
# Requirement already satisfied: pywin32>=300 in c:\users\pclam\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel!=7.0.0,!=7.0.1->solara-server==1.61.0->solara-server[dev,starlette]==1.61.0->solara) (311)
# Requirement already satisfied: six>=1.5 in c:\users\pclam\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->jupyter-client->solara-server==1.61.0->solara-server[dev,starlette]==1.61.0->solara) (1.17.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\pclam\anaconda3\lib\site-packages (from reacton>=1.9->solara-ui==1.61.0->solara-ui[all]==1.61.0->solara) (4.15.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\pclam\anaconda3\lib\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel!=7.0.0,!=7.0.1->solara-server==1.61.0->solara-server[dev,starlette]==1.61.0->solara) (3.0.0)
# Requirement already satisfied: pure_eval in c:\users\pclam\anaconda3\lib\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel!=7.0.0,!=7.0.1->solara-server==1.61.0->solara-server[dev,starlette]==1.61.0->solara) (0.2.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\pclam\anaconda3\lib\site-packages (from jinja2->solara-server==1.61.0->solara-server[dev,starlette]==1.61.0->solara) (3.0.2)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\pclam\anaconda3\lib\site-packages (from nbformat->solara-server==1.61.0->solara-server[dev,starlette]==1.61.0->solara) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\pclam\anaconda3\lib\site-packages (from nbformat->solara-server==1.61.0->solara-server[dev,starlette]==1.61.0->solara) (4.25.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\pclam\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat->solara-server==1.61.0->solara-server[dev,starlette]==1.61.0->solara) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\pclam\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat->solara-server==1.61.0->solara-server[dev,starlette]==1.61.0->solara) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\pclam\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat->solara-server==1.61.0->solara-server[dev,starlette]==1.61.0->solara) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\pclam\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat->solara-server==1.61.0->solara-server[dev,starlette]==1.61.0->solara) (0.28.0)
# Requirement already satisfied: pyyaml in c:\users\pclam\anaconda3\lib\site-packages (from pymdown-extensions->solara-ui[all]==1.61.0->solara) (6.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\pclam\anaconda3\lib\site-packages (from requests->solara-ui==1.61.0->solara-ui[all]==1.61.0->solara) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pclam\anaconda3\lib\site-packages (from requests->solara-ui==1.61.0->solara-ui[all]==1.61.0->solara) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\pclam\anaconda3\lib\site-packages (from requests->solara-ui==1.61.0->solara-ui[all]==1.61.0->solara) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pclam\anaconda3\lib\site-packages (from requests->solara-ui==1.61.0->solara-ui[all]==1.61.0->solara) (2026.7.22)
# Requirement already satisfied: rich>=12 in c:\users\pclam\anaconda3\lib\site-packages (from rich-click->solara-server==1.61.0->solara-server[dev,starlette]==1.61.0->solara) (14.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\pclam\anaconda3\lib\site-packages (from rich>=12->rich-click->solara-server==1.61.0->solara-server[dev,starlette]==1.61.0->solara) (2.2.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\pclam\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=12->rich-click->solara-server==1.61.0->solara-server[dev,starlette]==1.61.0->solara) (0.1.2)
# Requirement already satisfied: anyio<5,>=3.6.2 in c:\users\pclam\anaconda3\lib\site-packages (from starlette->solara-server[dev,starlette]==1.61.0->solara) (4.10.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\pclam\anaconda3\lib\site-packages (from anyio<5,>=3.6.2->starlette->solara-server[dev,starlette]==1.61.0->solara) (1.3.0)
# Requirement already satisfied: h11>=0.8 in c:\users\pclam\anaconda3\lib\site-packages (from uvicorn->solara-server[dev,starlette]==1.61.0->solara) (0.16.0)

# %%
# !solara run restaurant_app.py --port=9000
